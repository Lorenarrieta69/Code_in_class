# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorenarrieta69/Code_in_class/blob/main/Copia_de_examp_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Exam 2

# %%
import pandas as pd 
import numpy as np

# %% [markdown]
# ## 1.Import the Data

# %%
# Save the file path
p1 = '/content/Data.xlsx'

# Read file
ed = pd.read_excel(p1)

# Check
ed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 64 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  13 non-null     object
#  1   Country Code  13 non-null     object
#  2   1960          13 non-null     float64
#  3   1961          13 non-null     float64
#  4   1962          13 non-null     float64
#  5   1963          13 non-null     float64
#  6   1964          13 non-null     float64
#  7   1965          13 non-null     float64
#  8   1966          13 non-null     float64
#  9   1967          13 non-null     float64
#  10  1968          13 non-null     float64
#  11  1969          13 non-null     float64
#  12  1970          13 non-null     float64
#  13  1971          13 non-null     float64
#  14  1972          13 non-null     float64
#  15  1973          13 non-null     float64
#  16  1974          13 non-null     float64
# ...

# %%
# Save the file path
p2 = '/content/Data.csv'
# Read file
cd = pd.read_csv(p2, sep = ';')

# Check
cd.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 64 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Name  13 non-null     object
#  1   Country Code  13 non-null     object
#  2   1960          13 non-null     float64
#  3   1961          13 non-null     float64
#  4   1962          13 non-null     float64
#  5   1963          13 non-null     float64
#  6   1964          13 non-null     float64
#  7   1965          13 non-null     float64
#  8   1966          13 non-null     float64
#  9   1967          13 non-null     float64
#  10  1968          13 non-null     float64
#  11  1969          13 non-null     float64
#  12  1970          13 non-null     float64
#  13  1971          13 non-null     float64
#  14  1972          13 non-null     float64
#  15  1973          13 non-null     float64
#  16  1974          13 non-null     float64
# ...

# %%
# Save the file path
p3 = '/content/Data.txt'
# Read file
td = pd.read_csv(p3, sep = '\t')

# Check
td.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Country Code  62 non-null     int64
#  1   BOL           62 non-null     float64
#  2   CAN           62 non-null     float64
#  3   CHN           62 non-null     float64
#  4   COL           62 non-null     float64
#  5   DEU           62 non-null     float64
#  6   FRA           62 non-null     float64
#  7   GBR           62 non-null     float64
#  8   ITA           62 non-null     float64
#  9   JPN           62 non-null     float64
#  10  KOR           62 non-null     float64
#  11  NLD           62 non-null     float64
#  12  RUS           62 non-null     float64
#  13  USA           62 non-null     int64
# dtypes: float64(12), int64(2)
# memory usage: 6.9 KB

# %% [markdown]
# ## 2.Explore

# %% [markdown]
# ### 2.1. Preview

# %%
# Preview 0
td.shape
# Out:
# (62, 14)

# %%
# Preview 1
td.head()
# Out:
#    Country Code         BOL          CAN          CHN         COL  DEU  \
# 0          1960   89.483965     0.000000  2644.406532  594.894695  0.0
# 1          1961   94.909765  7480.255449  1746.689414  627.934716  0.0
# 2          1962  113.858328  7594.733340  1372.979121  605.929809  0.0
# 3          1963  126.128984  7854.369043  1450.158421  597.285656  0.0
# 4          1964  126.629827  8918.902585  1710.130799  755.727700  0.0
#
#             FRA  GBR  ITA  JPN         KOR  NLD  RUS  USA
# 0   7703.448807  0.0  0.0  0.0  474.140116  0.0  0.0    0
# 1   8273.434930  0.0  0.0  0.0  337.523800  0.0  0.0    0
# 2   9042.716900  0.0  0.0  0.0  438.924765  0.0  0.0    0
# 3  10367.369960  0.0  0.0  0.0  584.540710  0.0  0.0    0
# 4  12137.117080  0.0  0.0  0.0  428.205544  0.0  0.0    0

# %% [markdown]
# ### 2.2. Add more info

# %%
# Extract the year
ed['Year'] = ed['Date'].ed.year

# Extract the Quarter
ed['Quarter'] = ed['DATE'].ed.quarter

# Extract the Month
ed['Month'] = ed['DATE'].ed.month

# Extract the Week
ed['Week'] = ed['DATE'].ed.week

# Extract the Weekday
ed['Weekday'] = ed['DATE'].ed.weekday

# Extract the Day
ed['Day'] = ed['DATE'].ed.Day
ed.head()

# %% [markdown]
# ### 2.3. Reindex

# %%
# Single Index
td = td.set_index('Country Code')
td.head()
# Out:
#                      BOL          CAN          CHN         COL  DEU  \
# Country Code
# 1960           89.483965     0.000000  2644.406532  594.894695  0.0
# 1961           94.909765  7480.255449  1746.689414  627.934716  0.0
# 1962          113.858328  7594.733340  1372.979121  605.929809  0.0
# 1963          126.128984  7854.369043  1450.158421  597.285656  0.0
# 1964          126.629827  8918.902585  1710.130799  755.727700  0.0
#
#                        FRA  GBR  ITA  JPN         KOR  NLD  RUS  USA
# Country Code
# 1960           7703.448807  0.0  0.0  0.0  474.140116  0.0  0.0    0
# 1961           8273.434930  0.0  0.0  0.0  337.523800  0.0  0.0    0
# 1962           9042.716900  0.0  0.0  0.0  438.924765  0.0  0.0    0
# 1963          10367.369960  0.0  0.0  0.0  584.540710  0.0  0.0    0
# 1964          12137.117080  0.0  0.0  0.0  428.205544  0.0  0.0    0

# %%
# Multiple index

td2 = ed
td2 = ed2.set_index([''])

# %%
# Import library
import plotly.express as px

# %%
fig = px.line(td, title = "Imports of goods and services (US$ at current prices)")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Title
fig.update_layout(title = "Imports of goods and services (US$ at current prices)", 
                  title_font_size = 25,
                  title_x = 0.5)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
