# %% [markdown]
# <a href="https://colab.research.google.com/github/Lorenarrieta69/Code_in_class/blob/main/00_Basics_of_MD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Heading level 1

# %% [markdown]
# ## Head level 2

# %% [markdown]
# #text formating

# %% [markdown]
# ## Bold
# **car**
# **my car es geen and very old**

# %% [markdown]
# ##italics
# *car*
#
# *My car es green and very old*

# %% [markdown]
# ## combine bold and italics
# ***This text has hold and italics formant***

# %% [markdown]
# ## underline
# we dont, because underline is reserved for links

# %% [markdown]
# List

# %% [markdown]
# ## unoderder list
# **Grocery List**
# * Rice
# * Eggs
# * Bread
# * Coffe

# %% [markdown]
# ## onderes list
# **Table contents**
# 1. Introdution
# 2. Reference frame
#
# jdjdjdjdj
#
# 3. Results

# %% [markdown]
# ##Nested list
#  a nestee list a list that has another list inside it
#
# **Example**
# 1. A
#
#     1.1. a
#
#     1.2. m
# 2. b
#
#    * b

# %% [markdown]
# ## Inserts
# use this we you want to connet to extermal sources
# (alt d + ctrl c + v)
#
# https://www.lasalle.edu.co/
#
# [La salle](https://www.lasalle.edu.co/)

# %% [markdown]
# #imagen
# # ![image1] [texto del vínculo](https://)(![image.png](v)![image.png](data:image/png;base64,...)

# %% [markdown]
# # **Tables**
#
# | a | b | c |
# |---|---|---|
# | 1 | 2 | 3 |
# | L | O | R |

# %% [markdown]
# # **Equations**
# ## Inline equations
#
# This in the pytagoras thearem $c^2=a^2+b^2$
#
# Latex
# $x_{1}+x_{2}$
